# %%
import pandas as pd

# %%
df = pd.read_csv("US_Accidents_March23.csv")

# %%
df.head(5)
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
missing_df = df.isna().sum() * 100 / len(df)

# %%
pd.DataFrame({'column_name': df.columns, 'percent_missing': missing_df.values})
# Out:
#               column_name  percent_missing
# 0                      ID         0.000000
# 1                  Source         0.000000
# 2                Severity         0.000000
# 3              Start_Time         0.000000
# 4                End_Time         0.000000
# 5               Start_Lat         0.000000
# 6               Start_Lng         0.000000
# 7                 End_Lat        44.029355
# 8                 End_Lng        44.029355
# 9            Distance(mi)         0.000000
# 10            Description         0.000065
# 11                 Street         0.140637
# 12                   City         0.003274
# 13                 County         0.000000
# 14                  State         0.000000
# 15                Zipcode         0.024779
# 16                Country         0.000000
# 17               Timezone         0.101030
# 18           Airport_Code         0.292881
# 19      Weather_Timestamp         1.555666
# 20         Temperature(F)         2.120143
# ...

# %%
df.drop(["End_Lat", "End_Lng"], axis=1, inplace=True)

# %%
df["Wind_Chill(F)"] = df["Wind_Chill(F)"].fillna(0)
df["Precipitation(in)"] = df["Precipitation(in)"].fillna(0)

# %%
df.dropna(inplace=True)

# %%
# convert the Start_Time & End_Time Variable into Datetime Feature
df.Start_Time = pd.to_datetime(df.Start_Time, format='mixed')
df.End_Time = pd.to_datetime(df.End_Time, format='mixed')

# %%
# dependent variable is basically levels : 4 levels
# First variable : City
# city variable will be converted into these variables : 1. Cali, 2. FL 3. Oregon, 4. Texas,  5. New York, 6. Minnesota, 7. virginia, 8. North Carolina,9. Pennsylvania,10. Illinois,11.other
# Timezone ariable will be converted into these variables : 1. US Easter, 2. FL 3. Oregon, 4. Texas,  5. New York, 6. Minnesota, 7. vir

###### add above
